# %%
import numpy as np
import pandas as pd
import cobra.test
import os

from os.path import join

from time import time


from cobra.flux_analysis import (
    single_gene_deletion, single_reaction_deletion, double_gene_deletion,
    double_reaction_deletion)

a = cobra.io.read_sbml_model("iEC1344_C.xml")
# Out:
# Academic license - for non-commercial use only - expires 2023-02-21
# Using license file /home/schwartzlab/gurobi.lic

# %%
df= pd.read_csv('diff_saturated.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated anaerobic.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('diff_saturated study conditions.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('diff_saturated M9 media.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('diff_saturated lactose.csv')
f= df4.iloc[:, 1]

union = pd.Series(np.union1d(b, c))
intersect = pd.Series(np.intersect1d(b, c))
bigb2= union[~union.isin(intersect)]

union = pd.Series(np.union1d(b, d))
intersect = pd.Series(np.intersect1d(b, d))
bigb3= union[~union.isin(intersect)]

union = pd.Series(np.union1d(b, e))
intersect = pd.Series(np.intersect1d(b, e))
bigb4= union[~union.isin(intersect)]

union = pd.Series(np.union1d(b, f))
intersect = pd.Series(np.intersect1d(b, f))
bigb5= union[~union.isin(intersect)]



i= 0
l1= list()
l2= list()

while i < len(bigb2):
    
    if bigb2.values[i] in b.values and bigb2.values[i] not in c.values:
        l1.append(bigb2.values[i])
    elif bigb2.values[i] in c.values and bigb2.values[i] not in b.values:
        l2.append(bigb2.values[i])
    
    i= i+1

d1= pd.DataFrame(l1, columns=['Reaction names'])
d1.to_csv("Saturated in WT and not anaerobic conditions")
d2= pd.DataFrame(l2, columns=['Reaction names'])
d2.to_csv("Saturated in anaerobic and not WT conditions")



i= 0
l3= list()
l4= list()

while i < len(bigb3):
    
    if bigb3.values[i] in b.values and bigb3.values[i] not in d.values:
        l3.append(bigb3.values[i])
    elif bigb3.values[i] in d.values and bigb3.values[i] not in b.values:
        l4.append(bigb3.values[i])
    
    i= i+1

d3= pd.DataFrame(l3, columns=['Reaction names'])
d3.to_csv("Saturated in WT and not study conditions")
d4= pd.DataFrame(l4, columns=['Reaction names'])
d4.to_csv("Saturated in study and not WT conditions")



i= 0
l5= list()
l6= list()

while i < len(bigb4):
    
    if bigb4.values[i] in b.values and bigb4.values[i] not in e.values:
        l5.append(bigb4.values[i])
    elif bigb4.values[i] in e.values and bigb4.values[i] not in b.values:
        l6.append(bigb4.values[i])
    
    i= i+1

d5= pd.DataFrame(l5, columns=['Reaction names'])
d5.to_csv("Saturated in WT and not M9 media conditions")
d6= pd.DataFrame(l6, columns=['Reaction names'])
d6.to_csv("Saturated in M9 media and not WT conditions")



i= 0
l7= list()
l8= list()

while i < len(bigb5):
    
    if bigb5.values[i] in b.values and bigb5.values[i] not in f.values:
        l7.append(bigb5.values[i])
    elif bigb5.values[i] in f.values and bigb5.values[i] not in b.values:
        l8.append(bigb5.values[i])
    
    i= i+1

d7= pd.DataFrame(l7, columns=['Reaction names'])
d7.to_csv("Saturated in WT and not lactose conditions")
d8= pd.DataFrame(l8, columns=['Reaction names'])
d8.to_csv("Saturated in lactose and not WT conditions")

# %%
df= pd.read_csv('one feasible value reactions.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('one feasible value reactions anaerobic.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('one feasible value reactions study conditions.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('one feasible value reactions M9 media.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('one feasible value reactions lactose.csv')
f= df4.iloc[:, 1]

union = pd.Series(np.union1d(b, c))
intersect = pd.Series(np.intersect1d(b, c))
bigb2= union[~union.isin(intersect)]

union = pd.Series(np.union1d(b, d))
intersect = pd.Series(np.intersect1d(b, d))
bigb3= union[~union.isin(intersect)]

union = pd.Series(np.union1d(b, e))
intersect = pd.Series(np.intersect1d(b, e))
bigb4= union[~union.isin(intersect)]

union = pd.Series(np.union1d(b, f))
intersect = pd.Series(np.intersect1d(b, f))
bigb5= union[~union.isin(intersect)]



i= 0
l1= list()
l2= list()

while i < len(bigb2):
    
    if bigb2.values[i] in b.values and bigb2.values[i] not in c.values:
        l1.append(bigb2.values[i])
    elif bigb2.values[i] in c.values and bigb2.values[i] not in b.values:
        l2.append(bigb2.values[i])
    
    i= i+1

d1= pd.DataFrame(l1, columns=['Reaction names'])
d1.to_csv("One in WT and not anaerobic conditions")
d2= pd.DataFrame(l2, columns=['Reaction names'])
d2.to_csv("One in anaerobic and not WT conditions")



i= 0
l3= list()
l4= list()

while i < len(bigb3):
    
    if bigb3.values[i] in b.values and bigb3.values[i] not in d.values:
        l3.append(bigb3.values[i])
    elif bigb3.values[i] in d.values and bigb3.values[i] not in b.values:
        l4.append(bigb3.values[i])
    
    i= i+1

d3= pd.DataFrame(l3, columns=['Reaction names'])
d3.to_csv("One in WT and not study conditions")
d4= pd.DataFrame(l4, columns=['Reaction names'])
d4.to_csv("One in study and not WT conditions")



i= 0
l5= list()
l6= list()

while i < len(bigb4):
    
    if bigb4.values[i] in b.values and bigb4.values[i] not in e.values:
        l5.append(bigb4.values[i])
    elif bigb4.values[i] in e.values and bigb4.values[i] not in b.values:
        l6.append(bigb4.values[i])
    
    i= i+1

d5= pd.DataFrame(l5, columns=['Reaction names'])
d5.to_csv("One in WT and not M9 media conditions")
d6= pd.DataFrame(l6, columns=['Reaction names'])
d6.to_csv("One in M9 media and not WT conditions")



i= 0
l7= list()
l8= list()

while i < len(bigb5):
    
    if bigb5.values[i] in b.values and bigb5.values[i] not in f.values:
        l7.append(bigb5.values[i])
    elif bigb5.values[i] in f.values and bigb5.values[i] not in b.values:
        l8.append(bigb5.values[i])
    
    i= i+1

d7= pd.DataFrame(l7, columns=['Reaction names'])
d7.to_csv("One in WT and not lactose conditions")
d8= pd.DataFrame(l8, columns=['Reaction names'])
d8.to_csv("One in lactose and not WT conditions")

# %%
df= pd.read_csv('flat.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('flat anaerobic.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat study conditions.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('flat M9 media.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('flat lactose.csv')
f= df4.iloc[:, 1]

union = pd.Series(np.union1d(b, c))
intersect = pd.Series(np.intersect1d(b, c))
bigb2= union[~union.isin(intersect)]

union = pd.Series(np.union1d(b, d))
intersect = pd.Series(np.intersect1d(b, d))
bigb3= union[~union.isin(intersect)]

union = pd.Series(np.union1d(b, e))
intersect = pd.Series(np.intersect1d(b, e))
bigb4= union[~union.isin(intersect)]

union = pd.Series(np.union1d(b, f))
intersect = pd.Series(np.intersect1d(b, f))
bigb5= union[~union.isin(intersect)]



i= 0
l1= list()
l2= list()

while i < len(bigb2):
    
    if bigb2.values[i] in b.values and bigb2.values[i] not in c.values:
        l1.append(bigb2.values[i])
    elif bigb2.values[i] in c.values and bigb2.values[i] not in b.values:
        l2.append(bigb2.values[i])
    
    i= i+1

d1= pd.DataFrame(l1, columns=['Reaction names'])
d1.to_csv("flat in WT and not anaerobic conditions")
d2= pd.DataFrame(l2, columns=['Reaction names'])
d2.to_csv("flat in anaerobic and not WT conditions")



i= 0
l3= list()
l4= list()

while i < len(bigb3):
    
    if bigb3.values[i] in b.values and bigb3.values[i] not in d.values:
        l3.append(bigb3.values[i])
    elif bigb3.values[i] in d.values and bigb3.values[i] not in b.values:
        l4.append(bigb3.values[i])
    
    i= i+1

d3= pd.DataFrame(l3, columns=['Reaction names'])
d3.to_csv("flat in WT and not study conditions")
d4= pd.DataFrame(l4, columns=['Reaction names'])
d4.to_csv("flat in study and not WT conditions")



i= 0
l5= list()
l6= list()

while i < len(bigb4):
    
    if bigb4.values[i] in b.values and bigb4.values[i] not in e.values:
        l5.append(bigb4.values[i])
    elif bigb4.values[i] in e.values and bigb4.values[i] not in b.values:
        l6.append(bigb4.values[i])
    
    i= i+1

d5= pd.DataFrame(l5, columns=['Reaction names'])
d5.to_csv("flat in WT and not M9 media conditions")
d6= pd.DataFrame(l6, columns=['Reaction names'])
d6.to_csv("flat in M9 media and not WT conditions")



i= 0
l7= list()
l8= list()

while i < len(bigb5):
    
    if bigb5.values[i] in b.values and bigb5.values[i] not in f.values:
        l7.append(bigb5.values[i])
    elif bigb5.values[i] in f.values and bigb5.values[i] not in b.values:
        l8.append(bigb5.values[i])
    
    i= i+1

d7= pd.DataFrame(l7, columns=['Reaction names'])
d7.to_csv("flat in WT and not lactose conditions")
d8= pd.DataFrame(l8, columns=['Reaction names'])
d8.to_csv("flat in lactose and not WT conditions")

# %%
df= pd.read_csv('Ushaped_reactions.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('Ushaped_reactions anaerobic.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('Ushaped_reactions study conditions.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('Ushaped_reactions M9 media.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('Ushaped_reactions lactose.csv')
f= df4.iloc[:, 1]

union = pd.Series(np.union1d(b, c))
intersect = pd.Series(np.intersect1d(b, c))
bigb2= union[~union.isin(intersect)]

union = pd.Series(np.union1d(b, d))
intersect = pd.Series(np.intersect1d(b, d))
bigb3= union[~union.isin(intersect)]

union = pd.Series(np.union1d(b, e))
intersect = pd.Series(np.intersect1d(b, e))
bigb4= union[~union.isin(intersect)]

union = pd.Series(np.union1d(b, f))
intersect = pd.Series(np.intersect1d(b, f))
bigb5= union[~union.isin(intersect)]



i= 0
l1= list()
l2= list()

while i < len(bigb2):
    
    if bigb2.values[i] in b.values and bigb2.values[i] not in c.values:
        l1.append(bigb2.values[i])
    elif bigb2.values[i] in c.values and bigb2.values[i] not in b.values:
        l2.append(bigb2.values[i])
    
    i= i+1

d1= pd.DataFrame(l1, columns=['Reaction names'])
d1.to_csv("Ushaped in WT and not anaerobic conditions")
d2= pd.DataFrame(l2, columns=['Reaction names'])
d2.to_csv("Ushaped in anaerobic and not WT conditions")



i= 0
l3= list()
l4= list()

while i < len(bigb3):
    
    if bigb3.values[i] in b.values and bigb3.values[i] not in d.values:
        l3.append(bigb3.values[i])
    elif bigb3.values[i] in d.values and bigb3.values[i] not in b.values:
        l4.append(bigb3.values[i])
    
    i= i+1

d3= pd.DataFrame(l3, columns=['Reaction names'])
d3.to_csv("Ushaped in WT and not study conditions")
d4= pd.DataFrame(l4, columns=['Reaction names'])
d4.to_csv("Ushaped in study and not WT conditions")



i= 0
l5= list()
l6= list()

while i < len(bigb4):
    
    if bigb4.values[i] in b.values and bigb4.values[i] not in e.values:
        l5.append(bigb4.values[i])
    elif bigb4.values[i] in e.values and bigb4.values[i] not in b.values:
        l6.append(bigb4.values[i])
    
    i= i+1

d5= pd.DataFrame(l5, columns=['Reaction names'])
d5.to_csv("Ushaped in WT and not M9 media conditions")
d6= pd.DataFrame(l6, columns=['Reaction names'])
d6.to_csv("Ushaped in M9 media and not WT conditions")



i= 0
l7= list()
l8= list()

while i < len(bigb5):
    
    if bigb5.values[i] in b.values and bigb5.values[i] not in f.values:
        l7.append(bigb5.values[i])
    elif bigb5.values[i] in f.values and bigb5.values[i] not in b.values:
        l8.append(bigb5.values[i])
    
    i= i+1

d7= pd.DataFrame(l7, columns=['Reaction names'])
d7.to_csv("Ushaped in WT and not lactose conditions")
d8= pd.DataFrame(l8, columns=['Reaction names'])
d8.to_csv("Ushaped in lactose and not WT conditions")

# %%
df= pd.read_csv('monotonically decreasing and stable reactions.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('monotonically decreasing and stable reactions anaerobic.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('monotonically decreasing and stable reactions study conditions.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('monotonically decreasing and stable reactions M9 media.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('monotonically decreasing and stable reactions lactose.csv')
f= df4.iloc[:, 1]

union = pd.Series(np.union1d(b, c))
intersect = pd.Series(np.intersect1d(b, c))
bigb2= union[~union.isin(intersect)]

union = pd.Series(np.union1d(b, d))
intersect = pd.Series(np.intersect1d(b, d))
bigb3= union[~union.isin(intersect)]

union = pd.Series(np.union1d(b, e))
intersect = pd.Series(np.intersect1d(b, e))
bigb4= union[~union.isin(intersect)]

union = pd.Series(np.union1d(b, f))
intersect = pd.Series(np.intersect1d(b, f))
bigb5= union[~union.isin(intersect)]



i= 0
l1= list()
l2= list()

while i < len(bigb2):
    
    if bigb2.values[i] in b.values and bigb2.values[i] not in c.values:
        l1.append(bigb2.values[i])
    elif bigb2.values[i] in c.values and bigb2.values[i] not in b.values:
        l2.append(bigb2.values[i])
    
    i= i+1

d1= pd.DataFrame(l1, columns=['Reaction names'])
d1.to_csv("monotonically decreasing and stable in WT and not anaerobic conditions")
d2= pd.DataFrame(l2, columns=['Reaction names'])
d2.to_csv("monotonically decreasing and stable in anaerobic and not WT conditions")



i= 0
l3= list()
l4= list()

while i < len(bigb3):
    
    if bigb3.values[i] in b.values and bigb3.values[i] not in d.values:
        l3.append(bigb3.values[i])
    elif bigb3.values[i] in d.values and bigb3.values[i] not in b.values:
        l4.append(bigb3.values[i])
    
    i= i+1

d3= pd.DataFrame(l3, columns=['Reaction names'])
d3.to_csv("monotonically decreasing and stable in WT and not study conditions")
d4= pd.DataFrame(l4, columns=['Reaction names'])
d4.to_csv("monotonically decreasing and stable in study and not WT conditions")



i= 0
l5= list()
l6= list()

while i < len(bigb4):
    
    if bigb4.values[i] in b.values and bigb4.values[i] not in e.values:
        l5.append(bigb4.values[i])
    elif bigb4.values[i] in e.values and bigb4.values[i] not in b.values:
        l6.append(bigb4.values[i])
    
    i= i+1

d5= pd.DataFrame(l5, columns=['Reaction names'])
d5.to_csv("monotonically decreasing and stable in WT and not M9 media conditions")
d6= pd.DataFrame(l6, columns=['Reaction names'])
d6.to_csv("monotonically decreasing and stable in M9 media and not WT conditions")



i= 0
l7= list()
l8= list()

while i < len(bigb5):
    
    if bigb5.values[i] in b.values and bigb5.values[i] not in f.values:
        l7.append(bigb5.values[i])
    elif bigb5.values[i] in f.values and bigb5.values[i] not in b.values:
        l8.append(bigb5.values[i])
    
    i= i+1

d7= pd.DataFrame(l7, columns=['Reaction names'])
d7.to_csv("monotonically decreasing and stable in WT and not lactose conditions")
d8= pd.DataFrame(l8, columns=['Reaction names'])
d8.to_csv("monotonically decreasing and stable in lactose and not WT conditions")

# %%
df= pd.read_csv('monotonically decreasing only reactions.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('monotonically decreasing only reactions anaerobic.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('monotonically decreasing only reactions study conditions.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('monotonically decreasing only reactions M9 media.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('monotonically decreasing only reactions lactose.csv')
f= df4.iloc[:, 1]

union = pd.Series(np.union1d(b, c))
intersect = pd.Series(np.intersect1d(b, c))
bigb2= union[~union.isin(intersect)]

union = pd.Series(np.union1d(b, d))
intersect = pd.Series(np.intersect1d(b, d))
bigb3= union[~union.isin(intersect)]

union = pd.Series(np.union1d(b, e))
intersect = pd.Series(np.intersect1d(b, e))
bigb4= union[~union.isin(intersect)]

union = pd.Series(np.union1d(b, f))
intersect = pd.Series(np.intersect1d(b, f))
bigb5= union[~union.isin(intersect)]



i= 0
l1= list()
l2= list()

while i < len(bigb2):
    
    if bigb2.values[i] in b.values and bigb2.values[i] not in c.values:
        l1.append(bigb2.values[i])
    elif bigb2.values[i] in c.values and bigb2.values[i] not in b.values:
        l2.append(bigb2.values[i])
    
    i= i+1

d1= pd.DataFrame(l1, columns=['Reaction names'])
d1.to_csv("monotonically decreasing only in WT and not anaerobic conditions")
d2= pd.DataFrame(l2, columns=['Reaction names'])
d2.to_csv("monotonically decreasing only in anaerobic and not WT conditions")



i= 0
l3= list()
l4= list()

while i < len(bigb3):
    
    if bigb3.values[i] in b.values and bigb3.values[i] not in d.values:
        l3.append(bigb3.values[i])
    elif bigb3.values[i] in d.values and bigb3.values[i] not in b.values:
        l4.append(bigb3.values[i])
    
    i= i+1

d3= pd.DataFrame(l3, columns=['Reaction names'])
d3.to_csv("monotonically decreasing only in WT and not study conditions")
d4= pd.DataFrame(l4, columns=['Reaction names'])
d4.to_csv("monotonically decreasing only in study and not WT conditions")



i= 0
l5= list()
l6= list()

while i < len(bigb4):
    
    if bigb4.values[i] in b.values and bigb4.values[i] not in e.values:
        l5.append(bigb4.values[i])
    elif bigb4.values[i] in e.values and bigb4.values[i] not in b.values:
        l6.append(bigb4.values[i])
    
    i= i+1

d5= pd.DataFrame(l5, columns=['Reaction names'])
d5.to_csv("monotonically decreasing only in WT and not M9 media conditions")
d6= pd.DataFrame(l6, columns=['Reaction names'])
d6.to_csv("monotonically decreasing only in M9 media and not WT conditions")



i= 0
l7= list()
l8= list()

while i < len(bigb5):
    
    if bigb5.values[i] in b.values and bigb5.values[i] not in f.values:
        l7.append(bigb5.values[i])
    elif bigb5.values[i] in f.values and bigb5.values[i] not in b.values:
        l8.append(bigb5.values[i])
    
    i= i+1

d7= pd.DataFrame(l7, columns=['Reaction names'])
d7.to_csv("monotonically decreasing only in WT and not lactose conditions")
d8= pd.DataFrame(l8, columns=['Reaction names'])
d8.to_csv("monotonically decreasing only in lactose and not WT conditions")

# %%
df= pd.read_csv('monotonically increasing only reactions.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('monotonically increasing only reactions anaerobic.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('monotonically increasing only reactions study conditions.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('monotonically increasing only reactions M9 media.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('monotonically increasing only reactions lactose.csv')
f= df4.iloc[:, 1]

union = pd.Series(np.union1d(b, c))
intersect = pd.Series(np.intersect1d(b, c))
bigb2= union[~union.isin(intersect)]

union = pd.Series(np.union1d(b, d))
intersect = pd.Series(np.intersect1d(b, d))
bigb3= union[~union.isin(intersect)]

union = pd.Series(np.union1d(b, e))
intersect = pd.Series(np.intersect1d(b, e))
bigb4= union[~union.isin(intersect)]

union = pd.Series(np.union1d(b, f))
intersect = pd.Series(np.intersect1d(b, f))
bigb5= union[~union.isin(intersect)]



i= 0
l1= list()
l2= list()

while i < len(bigb2):
    
    if bigb2.values[i] in b.values and bigb2.values[i] not in c.values:
        l1.append(bigb2.values[i])
    elif bigb2.values[i] in c.values and bigb2.values[i] not in b.values:
        l2.append(bigb2.values[i])
    
    i= i+1

d1= pd.DataFrame(l1, columns=['Reaction names'])
d1.to_csv("monotonically increasing only in WT and not anaerobic conditions")
d2= pd.DataFrame(l2, columns=['Reaction names'])
d2.to_csv("monotonically increasing only in anaerobic and not WT conditions")



i= 0
l3= list()
l4= list()

while i < len(bigb3):
    
    if bigb3.values[i] in b.values and bigb3.values[i] not in d.values:
        l3.append(bigb3.values[i])
    elif bigb3.values[i] in d.values and bigb3.values[i] not in b.values:
        l4.append(bigb3.values[i])
    
    i= i+1

d3= pd.DataFrame(l3, columns=['Reaction names'])
d3.to_csv("monotonically increasing only in WT and not study conditions")
d4= pd.DataFrame(l4, columns=['Reaction names'])
d4.to_csv("monotonically increasing only in study and not WT conditions")



i= 0
l5= list()
l6= list()

while i < len(bigb4):
    
    if bigb4.values[i] in b.values and bigb4.values[i] not in e.values:
        l5.append(bigb4.values[i])
    elif bigb4.values[i] in e.values and bigb4.values[i] not in b.values:
        l6.append(bigb4.values[i])
    
    i= i+1

d5= pd.DataFrame(l5, columns=['Reaction names'])
d5.to_csv("monotonically increasing only in WT and not M9 media conditions")
d6= pd.DataFrame(l6, columns=['Reaction names'])
d6.to_csv("monotonically increasing only in M9 media and not WT conditions")



i= 0
l7= list()
l8= list()

while i < len(bigb5):
    
    if bigb5.values[i] in b.values and bigb5.values[i] not in f.values:
        l7.append(bigb5.values[i])
    elif bigb5.values[i] in f.values and bigb5.values[i] not in b.values:
        l8.append(bigb5.values[i])
    
    i= i+1

d7= pd.DataFrame(l7, columns=['Reaction names'])
d7.to_csv("monotonically increasing only in WT and not lactose conditions")
d8= pd.DataFrame(l8, columns=['Reaction names'])
d8.to_csv("monotonically increasing only in lactose and not WT conditions")

# %%
df= pd.read_csv('monotonically increasing and stable reactions.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('monotonically increasing and stable reactions anaerobic.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('monotonically increasing and stable reactions study conditions.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('monotonically increasing and stable reactions M9 media.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('monotonically increasing and stable reactions lactose.csv')
f= df4.iloc[:, 1]

union = pd.Series(np.union1d(b, c))
intersect = pd.Series(np.intersect1d(b, c))
bigb2= union[~union.isin(intersect)]

union = pd.Series(np.union1d(b, d))
intersect = pd.Series(np.intersect1d(b, d))
bigb3= union[~union.isin(intersect)]

union = pd.Series(np.union1d(b, e))
intersect = pd.Series(np.intersect1d(b, e))
bigb4= union[~union.isin(intersect)]

union = pd.Series(np.union1d(b, f))
intersect = pd.Series(np.intersect1d(b, f))
bigb5= union[~union.isin(intersect)]



i= 0
l1= list()
l2= list()

while i < len(bigb2):
    
    if bigb2.values[i] in b.values and bigb2.values[i] not in c.values:
        l1.append(bigb2.values[i])
    elif bigb2.values[i] in c.values and bigb2.values[i] not in b.values:
        l2.append(bigb2.values[i])
    
    i= i+1

d1= pd.DataFrame(l1, columns=['Reaction names'])
d1.to_csv("monotonically increasing and stable in WT and not anaerobic conditions")
d2= pd.DataFrame(l2, columns=['Reaction names'])
d2.to_csv("monotonically increasing and stable in anaerobic and not WT conditions")



i= 0
l3= list()
l4= list()

while i < len(bigb3):
    
    if bigb3.values[i] in b.values and bigb3.values[i] not in d.values:
        l3.append(bigb3.values[i])
    elif bigb3.values[i] in d.values and bigb3.values[i] not in b.values:
        l4.append(bigb3.values[i])
    
    i= i+1

d3= pd.DataFrame(l3, columns=['Reaction names'])
d3.to_csv("monotonically increasing and stable in WT and not study conditions")
d4= pd.DataFrame(l4, columns=['Reaction names'])
d4.to_csv("monotonically increasing and stable in study and not WT conditions")



i= 0
l5= list()
l6= list()

while i < len(bigb4):
    
    if bigb4.values[i] in b.values and bigb4.values[i] not in e.values:
        l5.append(bigb4.values[i])
    elif bigb4.values[i] in e.values and bigb4.values[i] not in b.values:
        l6.append(bigb4.values[i])
    
    i= i+1

d5= pd.DataFrame(l5, columns=['Reaction names'])
d5.to_csv("monotonically increasing and stable in WT and not M9 media conditions")
d6= pd.DataFrame(l6, columns=['Reaction names'])
d6.to_csv("monotonically increasing and stable in M9 media and not WT conditions")



i= 0
l7= list()
l8= list()

while i < len(bigb5):
    
    if bigb5.values[i] in b.values and bigb5.values[i] not in f.values:
        l7.append(bigb5.values[i])
    elif bigb5.values[i] in f.values and bigb5.values[i] not in b.values:
        l8.append(bigb5.values[i])
    
    i= i+1

d7= pd.DataFrame(l7, columns=['Reaction names'])
d7.to_csv("monotonically increasing and stable in WT and not lactose conditions")
d8= pd.DataFrame(l8, columns=['Reaction names'])
d8.to_csv("monotonically increasing and stable in lactose and not WT conditions")

# %%
df= pd.read_csv('increasing and decreasing and stable reactions.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('increasing and decreasing and stable reactions anaerobic.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('increasing and decreasing and stable reactions study conditions.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('increasing and decreasing and stable reactions M9 media.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('increasing and decreasing and stable reactions lactose.csv')
f= df4.iloc[:, 1]

union = pd.Series(np.union1d(b, c))
intersect = pd.Series(np.intersect1d(b, c))
bigb2= union[~union.isin(intersect)]

union = pd.Series(np.union1d(b, d))
intersect = pd.Series(np.intersect1d(b, d))
bigb3= union[~union.isin(intersect)]

union = pd.Series(np.union1d(b, e))
intersect = pd.Series(np.intersect1d(b, e))
bigb4= union[~union.isin(intersect)]

union = pd.Series(np.union1d(b, f))
intersect = pd.Series(np.intersect1d(b, f))
bigb5= union[~union.isin(intersect)]



i= 0
l1= list()
l2= list()

while i < len(bigb2):
    
    if bigb2.values[i] in b.values and bigb2.values[i] not in c.values:
        l1.append(bigb2.values[i])
    elif bigb2.values[i] in c.values and bigb2.values[i] not in b.values:
        l2.append(bigb2.values[i])
    
    i= i+1

d1= pd.DataFrame(l1, columns=['Reaction names'])
d1.to_csv("increasing and decreasing and stable in WT and not anaerobic conditions")
d2= pd.DataFrame(l2, columns=['Reaction names'])
d2.to_csv("increasing and decreasing and stable in anaerobic and not WT conditions")



i= 0
l3= list()
l4= list()

while i < len(bigb3):
    
    if bigb3.values[i] in b.values and bigb3.values[i] not in d.values:
        l3.append(bigb3.values[i])
    elif bigb3.values[i] in d.values and bigb3.values[i] not in b.values:
        l4.append(bigb3.values[i])
    
    i= i+1

d3= pd.DataFrame(l3, columns=['Reaction names'])
d3.to_csv("increasing and decreasing and stable in WT and not study conditions")
d4= pd.DataFrame(l4, columns=['Reaction names'])
d4.to_csv("increasing and decreasing and stable in study and not WT conditions")



i= 0
l5= list()
l6= list()

while i < len(bigb4):
    
    if bigb4.values[i] in b.values and bigb4.values[i] not in e.values:
        l5.append(bigb4.values[i])
    elif bigb4.values[i] in e.values and bigb4.values[i] not in b.values:
        l6.append(bigb4.values[i])
    
    i= i+1

d5= pd.DataFrame(l5, columns=['Reaction names'])
d5.to_csv("increasing and decreasing and stable in WT and not M9 media conditions")
d6= pd.DataFrame(l6, columns=['Reaction names'])
d6.to_csv("increasing and decreasing and stable in M9 media and not WT conditions")



i= 0
l7= list()
l8= list()

while i < len(bigb5):
    
    if bigb5.values[i] in b.values and bigb5.values[i] not in f.values:
        l7.append(bigb5.values[i])
    elif bigb5.values[i] in f.values and bigb5.values[i] not in b.values:
        l8.append(bigb5.values[i])
    
    i= i+1

d7= pd.DataFrame(l7, columns=['Reaction names'])
d7.to_csv("increasing and decreasing and stable in WT and not lactose conditions")
d8= pd.DataFrame(l8, columns=['Reaction names'])
d8.to_csv("increasing and decreasing and stable in lactose and not WT conditions")

# %%
df= pd.read_csv('increasing and decreasing only reactions.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('increasing and decreasing only reactions anaerobic.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('increasing and decreasing only reactions study conditions.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('increasing and decreasing only reactions M9 media.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('increasing and decreasing only reactions lactose.csv')
f= df4.iloc[:, 1]

union = pd.Series(np.union1d(b, c))
intersect = pd.Series(np.intersect1d(b, c))
bigb2= union[~union.isin(intersect)]

union = pd.Series(np.union1d(b, d))
intersect = pd.Series(np.intersect1d(b, d))
bigb3= union[~union.isin(intersect)]

union = pd.Series(np.union1d(b, e))
intersect = pd.Series(np.intersect1d(b, e))
bigb4= union[~union.isin(intersect)]

union = pd.Series(np.union1d(b, f))
intersect = pd.Series(np.intersect1d(b, f))
bigb5= union[~union.isin(intersect)]



i= 0
l1= list()
l2= list()

while i < len(bigb2):
    
    if bigb2.values[i] in b.values and bigb2.values[i] not in c.values:
        l1.append(bigb2.values[i])
    elif bigb2.values[i] in c.values and bigb2.values[i] not in b.values:
        l2.append(bigb2.values[i])
    
    i= i+1

d1= pd.DataFrame(l1, columns=['Reaction names'])
d1.to_csv("increasing and decreasing only in WT and not anaerobic conditions")
d2= pd.DataFrame(l2, columns=['Reaction names'])
d2.to_csv("increasing and decreasing only in anaerobic and not WT conditions")



i= 0
l3= list()
l4= list()

while i < len(bigb3):
    
    if bigb3.values[i] in b.values and bigb3.values[i] not in d.values:
        l3.append(bigb3.values[i])
    elif bigb3.values[i] in d.values and bigb3.values[i] not in b.values:
        l4.append(bigb3.values[i])
    
    i= i+1

d3= pd.DataFrame(l3, columns=['Reaction names'])
d3.to_csv("increasing and decreasing only in WT and not study conditions")
d4= pd.DataFrame(l4, columns=['Reaction names'])
d4.to_csv("increasing and decreasing only in study and not WT conditions")



i= 0
l5= list()
l6= list()

while i < len(bigb4):
    
    if bigb4.values[i] in b.values and bigb4.values[i] not in e.values:
        l5.append(bigb4.values[i])
    elif bigb4.values[i] in e.values and bigb4.values[i] not in b.values:
        l6.append(bigb4.values[i])
    
    i= i+1

d5= pd.DataFrame(l5, columns=['Reaction names'])
d5.to_csv("increasing and decreasing only in WT and not M9 media conditions")
d6= pd.DataFrame(l6, columns=['Reaction names'])
d6.to_csv("increasing and decreasing only in M9 media and not WT conditions")



i= 0
l7= list()
l8= list()

while i < len(bigb5):
    
    if bigb5.values[i] in b.values and bigb5.values[i] not in f.values:
        l7.append(bigb5.values[i])
    elif bigb5.values[i] in f.values and bigb5.values[i] not in b.values:
        l8.append(bigb5.values[i])
    
    i= i+1

d7= pd.DataFrame(l7, columns=['Reaction names'])
d7.to_csv("increasing and decreasing only in WT and not lactose conditions")
d8= pd.DataFrame(l8, columns=['Reaction names'])
d8.to_csv("increasing and decreasing only in lactose and not WT conditions")

# %%
df= pd.read_csv('diff_saturated.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated anaerobic.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('diff_saturated study conditions.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('diff_saturated M9 media.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('diff_saturated lactose.csv')
f= df4.iloc[:, 1]

union = pd.Series(np.union1d(c, d))
intersect = pd.Series(np.intersect1d(c, d))
bigb2= union[~union.isin(intersect)]

union = pd.Series(np.union1d(c, e))
intersect = pd.Series(np.intersect1d(c, e))
bigb3= union[~union.isin(intersect)]

union = pd.Series(np.union1d(c, f))
intersect = pd.Series(np.intersect1d(c, f))
bigb4= union[~union.isin(intersect)]


i= 0
l1= list()
l2= list()

while i < len(bigb2):
    
    if bigb2.values[i] in c.values and bigb2.values[i] not in d.values:
        l1.append(bigb2.values[i])
    elif bigb2.values[i] in d.values and bigb2.values[i] not in c.values:
        l2.append(bigb2.values[i])
    
    i= i+1

d1= pd.DataFrame(l1, columns=['Reaction names'])
d1.to_csv("Saturated in anaerobic and not study conditions")
d2= pd.DataFrame(l2, columns=['Reaction names'])
d2.to_csv("Saturated in study and not anaerobic conditions")



i= 0
l3= list()
l4= list()

while i < len(bigb3):
    
    if bigb3.values[i] in c.values and bigb3.values[i] not in e.values:
        l3.append(bigb3.values[i])
    elif bigb3.values[i] in e.values and bigb3.values[i] not in c.values:
        l4.append(bigb3.values[i])
    
    i= i+1

d3= pd.DataFrame(l3, columns=['Reaction names'])
d3.to_csv("Saturated in anaerobic and not M9 media conditions")
d4= pd.DataFrame(l4, columns=['Reaction names'])
d4.to_csv("Saturated in M9 media and not anaerobic conditions")



i= 0
l5= list()
l6= list()

while i < len(bigb4):
    
    if bigb4.values[i] in c.values and bigb4.values[i] not in f.values:
        l5.append(bigb4.values[i])
    elif bigb4.values[i] in f.values and bigb4.values[i] not in c.values:
        l6.append(bigb4.values[i])
    
    i= i+1

d5= pd.DataFrame(l5, columns=['Reaction names'])
d5.to_csv("Saturated in anaerobic and not lactose conditions")
d6= pd.DataFrame(l6, columns=['Reaction names'])
d6.to_csv("Saturated in lactose and not anaerobic conditions")

# %%
df= pd.read_csv('one feasible value reactions.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('one feasible value reactions anaerobic.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('one feasible value reactions study conditions.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('one feasible value reactions M9 media.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('one feasible value reactions lactose.csv')
f= df4.iloc[:, 1]

union = pd.Series(np.union1d(c, d))
intersect = pd.Series(np.intersect1d(c, d))
bigb2= union[~union.isin(intersect)]

union = pd.Series(np.union1d(c, e))
intersect = pd.Series(np.intersect1d(c, e))
bigb3= union[~union.isin(intersect)]

union = pd.Series(np.union1d(c, f))
intersect = pd.Series(np.intersect1d(c, f))
bigb4= union[~union.isin(intersect)]


i= 0
l1= list()
l2= list()

while i < len(bigb2):
    
    if bigb2.values[i] in c.values and bigb2.values[i] not in d.values:
        l1.append(bigb2.values[i])
    elif bigb2.values[i] in d.values and bigb2.values[i] not in c.values:
        l2.append(bigb2.values[i])
    
    i= i+1

d1= pd.DataFrame(l1, columns=['Reaction names'])
d1.to_csv("One in anaerobic and not study conditions")
d2= pd.DataFrame(l2, columns=['Reaction names'])
d2.to_csv("One in study and not anaerobic conditions")



i= 0
l3= list()
l4= list()

while i < len(bigb3):
    
    if bigb3.values[i] in c.values and bigb3.values[i] not in e.values:
        l3.append(bigb3.values[i])
    elif bigb3.values[i] in e.values and bigb3.values[i] not in c.values:
        l4.append(bigb3.values[i])
    
    i= i+1

d3= pd.DataFrame(l3, columns=['Reaction names'])
d3.to_csv("One in anaerobic and not M9 media conditions")
d4= pd.DataFrame(l4, columns=['Reaction names'])
d4.to_csv("One in M9 media and not anaerobic conditions")



i= 0
l5= list()
l6= list()

while i < len(bigb4):
    
    if bigb4.values[i] in c.values and bigb4.values[i] not in f.values:
        l5.append(bigb4.values[i])
    elif bigb4.values[i] in f.values and bigb4.values[i] not in c.values:
        l6.append(bigb4.values[i])
    
    i= i+1

d5= pd.DataFrame(l5, columns=['Reaction names'])
d5.to_csv("One in anaerobic and not lactose conditions")
d6= pd.DataFrame(l6, columns=['Reaction names'])
d6.to_csv("One in lactose and not anaerobic conditions")

# %%
df= pd.read_csv('flat.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('flat anaerobic.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat study conditions.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('flat M9 media.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('flat lactose.csv')
f= df4.iloc[:, 1]

union = pd.Series(np.union1d(c, d))
intersect = pd.Series(np.intersect1d(c, d))
bigb2= union[~union.isin(intersect)]

union = pd.Series(np.union1d(c, e))
intersect = pd.Series(np.intersect1d(c, e))
bigb3= union[~union.isin(intersect)]

union = pd.Series(np.union1d(c, f))
intersect = pd.Series(np.intersect1d(c, f))
bigb4= union[~union.isin(intersect)]


i= 0
l1= list()
l2= list()

while i < len(bigb2):
    
    if bigb2.values[i] in c.values and bigb2.values[i] not in d.values:
        l1.append(bigb2.values[i])
    elif bigb2.values[i] in d.values and bigb2.values[i] not in c.values:
        l2.append(bigb2.values[i])
    
    i= i+1

d1= pd.DataFrame(l1, columns=['Reaction names'])
d1.to_csv("flat in anaerobic and not study conditions")
d2= pd.DataFrame(l2, columns=['Reaction names'])
d2.to_csv("flat in study and not anaerobic conditions")



i= 0
l3= list()
l4= list()

while i < len(bigb3):
    
    if bigb3.values[i] in c.values and bigb3.values[i] not in e.values:
        l3.append(bigb3.values[i])
    elif bigb3.values[i] in e.values and bigb3.values[i] not in c.values:
        l4.append(bigb3.values[i])
    
    i= i+1

d3= pd.DataFrame(l3, columns=['Reaction names'])
d3.to_csv("flat in anaerobic and not M9 media conditions")
d4= pd.DataFrame(l4, columns=['Reaction names'])
d4.to_csv("flat in M9 media and not anaerobic conditions")



i= 0
l5= list()
l6= list()

while i < len(bigb4):
    
    if bigb4.values[i] in c.values and bigb4.values[i] not in f.values:
        l5.append(bigb4.values[i])
    elif bigb4.values[i] in f.values and bigb4.values[i] not in c.values:
        l6.append(bigb4.values[i])
    
    i= i+1

d5= pd.DataFrame(l5, columns=['Reaction names'])
d5.to_csv("flat in anaerobic and not lactose conditions")
d6= pd.DataFrame(l6, columns=['Reaction names'])
d6.to_csv("flat in lactose and not anaerobic conditions")

# %%
df= pd.read_csv('Ushaped_reactions.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('Ushaped_reactions anaerobic.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('Ushaped_reactions study conditions.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('Ushaped_reactions M9 media.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('Ushaped_reactions lactose.csv')
f= df4.iloc[:, 1]

union = pd.Series(np.union1d(c, d))
intersect = pd.Series(np.intersect1d(c, d))
bigb2= union[~union.isin(intersect)]

union = pd.Series(np.union1d(c, e))
intersect = pd.Series(np.intersect1d(c, e))
bigb3= union[~union.isin(intersect)]

union = pd.Series(np.union1d(c, f))
intersect = pd.Series(np.intersect1d(c, f))
bigb4= union[~union.isin(intersect)]

i= 0
l1= list()
l2= list()

while i < len(bigb2):
    
    if bigb2.values[i] in c.values and bigb2.values[i] not in d.values:
        l1.append(bigb2.values[i])
    elif bigb2.values[i] in d.values and bigb2.values[i] not in c.values:
        l2.append(bigb2.values[i])
    
    i= i+1

d1= pd.DataFrame(l1, columns=['Reaction names'])
d1.to_csv("Ushaped in anaerobic and not study conditions")
d2= pd.DataFrame(l2, columns=['Reaction names'])
d2.to_csv("Ushaped in study and not anaerobic conditions")



i= 0
l3= list()
l4= list()

while i < len(bigb3):
    
    if bigb3.values[i] in c.values and bigb3.values[i] not in e.values:
        l3.append(bigb3.values[i])
    elif bigb3.values[i] in e.values and bigb3.values[i] not in c.values:
        l4.append(bigb3.values[i])
    
    i= i+1

d3= pd.DataFrame(l3, columns=['Reaction names'])
d3.to_csv("Ushaped in anaerobic and not M9 media conditions")
d4= pd.DataFrame(l4, columns=['Reaction names'])
d4.to_csv("Ushaped in M9 media and not anaerobic conditions")



i= 0
l5= list()
l6= list()

while i < len(bigb4):
    
    if bigb4.values[i] in c.values and bigb4.values[i] not in f.values:
        l5.append(bigb4.values[i])
    elif bigb4.values[i] in f.values and bigb4.values[i] not in c.values:
        l6.append(bigb4.values[i])
    
    i= i+1

d5= pd.DataFrame(l5, columns=['Reaction names'])
d5.to_csv("Ushaped in anaerobic and not lactose conditions")
d6= pd.DataFrame(l6, columns=['Reaction names'])
d6.to_csv("Ushaped in lactose and not anaerobic conditions")

# %%
df= pd.read_csv('monotonically decreasing and stable reactions.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('monotonically decreasing and stable reactions anaerobic.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('monotonically decreasing and stable reactions study conditions.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('monotonically decreasing and stable reactions M9 media.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('monotonically decreasing and stable reactions lactose.csv')
f= df4.iloc[:, 1]

union = pd.Series(np.union1d(c, d))
intersect = pd.Series(np.intersect1d(c, d))
bigb2= union[~union.isin(intersect)]

union = pd.Series(np.union1d(c, e))
intersect = pd.Series(np.intersect1d(c, e))
bigb3= union[~union.isin(intersect)]

union = pd.Series(np.union1d(c, f))
intersect = pd.Series(np.intersect1d(c, f))
bigb4= union[~union.isin(intersect)]


i= 0
l1= list()
l2= list()

while i < len(bigb2):
    
    if bigb2.values[i] in c.values and bigb2.values[i] not in d.values:
        l1.append(bigb2.values[i])
    elif bigb2.values[i] in d.values and bigb2.values[i] not in c.values:
        l2.append(bigb2.values[i])
    
    i= i+1

d1= pd.DataFrame(l1, columns=['Reaction names'])
d1.to_csv("monotonically decreasing and stable in anaerobic and not study conditions")
d2= pd.DataFrame(l2, columns=['Reaction names'])
d2.to_csv("monotonically decreasing and stable in study and not anaerobic conditions")



i= 0
l3= list()
l4= list()

while i < len(bigb3):
    
    if bigb3.values[i] in c.values and bigb3.values[i] not in e.values:
        l3.append(bigb3.values[i])
    elif bigb3.values[i] in e.values and bigb3.values[i] not in c.values:
        l4.append(bigb3.values[i])
    
    i= i+1

d3= pd.DataFrame(l3, columns=['Reaction names'])
d3.to_csv("monotonically decreasing and stable in anaerobic and not M9 media conditions")
d4= pd.DataFrame(l4, columns=['Reaction names'])
d4.to_csv("monotonically decreasing and stable in M9 media and not anaerobic conditions")



i= 0
l5= list()
l6= list()

while i < len(bigb4):
    
    if bigb4.values[i] in c.values and bigb4.values[i] not in f.values:
        l5.append(bigb4.values[i])
    elif bigb4.values[i] in f.values and bigb4.values[i] not in c.values:
        l6.append(bigb4.values[i])
    
    i= i+1

d5= pd.DataFrame(l5, columns=['Reaction names'])
d5.to_csv("monotonically decreasing and stable in anaerobic and not lactose conditions")
d6= pd.DataFrame(l6, columns=['Reaction names'])
d6.to_csv("monotonically decreasing and stable in lactose and not anaerobic conditions")

# %%
df= pd.read_csv('monotonically decreasing only reactions.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('monotonically decreasing only reactions anaerobic.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('monotonically decreasing only reactions study conditions.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('monotonically decreasing only reactions M9 media.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('monotonically decreasing only reactions lactose.csv')
f= df4.iloc[:, 1]

union = pd.Series(np.union1d(c, d))
intersect = pd.Series(np.intersect1d(c, d))
bigb2= union[~union.isin(intersect)]

union = pd.Series(np.union1d(c, e))
intersect = pd.Series(np.intersect1d(c, e))
bigb3= union[~union.isin(intersect)]

union = pd.Series(np.union1d(c, f))
intersect = pd.Series(np.intersect1d(c, f))
bigb4= union[~union.isin(intersect)]


i= 0
l1= list()
l2= list()

while i < len(bigb2):
    
    if bigb2.values[i] in c.values and bigb2.values[i] not in d.values:
        l1.append(bigb2.values[i])
    elif bigb2.values[i] in d.values and bigb2.values[i] not in c.values:
        l2.append(bigb2.values[i])
    
    i= i+1

d1= pd.DataFrame(l1, columns=['Reaction names'])
d1.to_csv("monotonically decreasing only in anaerobic and not study conditions")
d2= pd.DataFrame(l2, columns=['Reaction names'])
d2.to_csv("monotonically decreasing only in study and not anaerobic conditions")



i= 0
l3= list()
l4= list()

while i < len(bigb3):
    
    if bigb3.values[i] in c.values and bigb3.values[i] not in e.values:
        l3.append(bigb3.values[i])
    elif bigb3.values[i] in e.values and bigb3.values[i] not in c.values:
        l4.append(bigb3.values[i])
    
    i= i+1

d3= pd.DataFrame(l3, columns=['Reaction names'])
d3.to_csv("monotonically decreasing only in anaerobic and not M9 media conditions")
d4= pd.DataFrame(l4, columns=['Reaction names'])
d4.to_csv("monotonically decreasing only in M9 media and not anaerobic conditions")



i= 0
l5= list()
l6= list()

while i < len(bigb4):
    
    if bigb4.values[i] in c.values and bigb4.values[i] not in f.values:
        l5.append(bigb4.values[i])
    elif bigb4.values[i] in f.values and bigb4.values[i] not in c.values:
        l6.append(bigb4.values[i])
    
    i= i+1

d5= pd.DataFrame(l5, columns=['Reaction names'])
d5.to_csv("monotonically decreasing only in anaerobic and not lactose conditions")
d6= pd.DataFrame(l6, columns=['Reaction names'])
d6.to_csv("monotonically decreasing only in lactose and not anaerobic conditions")

# %%
df= pd.read_csv('monotonically increasing only reactions.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('monotonically increasing only reactions anaerobic.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('monotonically increasing only reactions study conditions.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('monotonically increasing only reactions M9 media.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('monotonically increasing only reactions lactose.csv')
f= df4.iloc[:, 1]

union = pd.Series(np.union1d(c, d))
intersect = pd.Series(np.intersect1d(c, d))
bigb2= union[~union.isin(intersect)]

union = pd.Series(np.union1d(c, e))
intersect = pd.Series(np.intersect1d(c, e))
bigb3= union[~union.isin(intersect)]

union = pd.Series(np.union1d(c, f))
intersect = pd.Series(np.intersect1d(c, f))
bigb4= union[~union.isin(intersect)]


i= 0
l1= list()
l2= list()

while i < len(bigb2):
    
    if bigb2.values[i] in c.values and bigb2.values[i] not in d.values:
        l1.append(bigb2.values[i])
    elif bigb2.values[i] in d.values and bigb2.values[i] not in c.values:
        l2.append(bigb2.values[i])
    
    i= i+1

d1= pd.DataFrame(l1, columns=['Reaction names'])
d1.to_csv("monotonically increasing only in anaerobic and not study conditions")
d2= pd.DataFrame(l2, columns=['Reaction names'])
d2.to_csv("monotonically increasing only in study and not anaerobic conditions")



i= 0
l3= list()
l4= list()

while i < len(bigb3):
    
    if bigb3.values[i] in c.values and bigb3.values[i] not in e.values:
        l3.append(bigb3.values[i])
    elif bigb3.values[i] in e.values and bigb3.values[i] not in c.values:
        l4.append(bigb3.values[i])
    
    i= i+1

d3= pd.DataFrame(l3, columns=['Reaction names'])
d3.to_csv("monotonically increasing only in anaerobic and not M9 media conditions")
d4= pd.DataFrame(l4, columns=['Reaction names'])
d4.to_csv("monotonically increasing only in M9 media and not anaerobic conditions")



i= 0
l5= list()
l6= list()

while i < len(bigb4):
    
    if bigb4.values[i] in c.values and bigb4.values[i] not in f.values:
        l5.append(bigb4.values[i])
    elif bigb4.values[i] in f.values and bigb4.values[i] not in c.values:
        l6.append(bigb4.values[i])
    
    i= i+1

d5= pd.DataFrame(l5, columns=['Reaction names'])
d5.to_csv("monotonically increasing only in anaerobic and not lactose conditions")
d6= pd.DataFrame(l6, columns=['Reaction names'])
d6.to_csv("monotonically increasing only in lactose and not anaerobic conditions")

# %%
df= pd.read_csv('monotonically increasing and stable reactions.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('monotonically increasing and stable reactions anaerobic.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('monotonically increasing and stable reactions study conditions.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('monotonically increasing and stable reactions M9 media.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('monotonically increasing and stable reactions lactose.csv')
f= df4.iloc[:, 1]

union = pd.Series(np.union1d(c, d))
intersect = pd.Series(np.intersect1d(c, d))
bigb2= union[~union.isin(intersect)]

union = pd.Series(np.union1d(c, e))
intersect = pd.Series(np.intersect1d(c, e))
bigb3= union[~union.isin(intersect)]

union = pd.Series(np.union1d(c, f))
intersect = pd.Series(np.intersect1d(c, f))
bigb4= union[~union.isin(intersect)]


i= 0
l1= list()
l2= list()

while i < len(bigb2):
    
    if bigb2.values[i] in c.values and bigb2.values[i] not in d.values:
        l1.append(bigb2.values[i])
    elif bigb2.values[i] in d.values and bigb2.values[i] not in c.values:
        l2.append(bigb2.values[i])
    
    i= i+1

d1= pd.DataFrame(l1, columns=['Reaction names'])
d1.to_csv("monotonically increasing and stable in anaerobic and not study conditions")
d2= pd.DataFrame(l2, columns=['Reaction names'])
d2.to_csv("monotonically increasing and stable in study and not anaerobic conditions")



i= 0
l3= list()
l4= list()

while i < len(bigb3):
    
    if bigb3.values[i] in c.values and bigb3.values[i] not in e.values:
        l3.append(bigb3.values[i])
    elif bigb3.values[i] in e.values and bigb3.values[i] not in c.values:
        l4.append(bigb3.values[i])
    
    i= i+1

d3= pd.DataFrame(l3, columns=['Reaction names'])
d3.to_csv("monotonically increasing and stable in anaerobic and not M9 media conditions")
d4= pd.DataFrame(l4, columns=['Reaction names'])
d4.to_csv("monotonically increasing and stable in M9 media and not anaerobic conditions")



i= 0
l5= list()
l6= list()

while i < len(bigb4):
    
    if bigb4.values[i] in c.values and bigb4.values[i] not in f.values:
        l5.append(bigb4.values[i])
    elif bigb4.values[i] in f.values and bigb4.values[i] not in c.values:
        l6.append(bigb4.values[i])
    
    i= i+1

d5= pd.DataFrame(l5, columns=['Reaction names'])
d5.to_csv("monotonically increasing and stable in anaerobic and not lactose conditions")
d6= pd.DataFrame(l6, columns=['Reaction names'])
d6.to_csv("monotonically increasing and stable in lactose and not anaerobic conditions")

# %%
df= pd.read_csv('increasing and decreasing and stable reactions.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('increasing and decreasing and stable reactions anaerobic.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('increasing and decreasing and stable reactions study conditions.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('increasing and decreasing and stable reactions M9 media.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('increasing and decreasing and stable reactions lactose.csv')
f= df4.iloc[:, 1]

union = pd.Series(np.union1d(c, d))
intersect = pd.Series(np.intersect1d(c, d))
bigb2= union[~union.isin(intersect)]

union = pd.Series(np.union1d(c, e))
intersect = pd.Series(np.intersect1d(c, e))
bigb3= union[~union.isin(intersect)]

union = pd.Series(np.union1d(c, f))
intersect = pd.Series(np.intersect1d(c, f))
bigb4= union[~union.isin(intersect)]


i= 0
l1= list()
l2= list()

while i < len(bigb2):
    
    if bigb2.values[i] in c.values and bigb2.values[i] not in d.values:
        l1.append(bigb2.values[i])
    elif bigb2.values[i] in d.values and bigb2.values[i] not in c.values:
        l2.append(bigb2.values[i])
    
    i= i+1

d1= pd.DataFrame(l1, columns=['Reaction names'])
d1.to_csv("increasing and decreasing and stable in anaerobic and not study conditions")
d2= pd.DataFrame(l2, columns=['Reaction names'])
d2.to_csv("increasing and decreasing and stable in study and not anaerobic conditions")



i= 0
l3= list()
l4= list()

while i < len(bigb3):
    
    if bigb3.values[i] in c.values and bigb3.values[i] not in e.values:
        l3.append(bigb3.values[i])
    elif bigb3.values[i] in e.values and bigb3.values[i] not in c.values:
        l4.append(bigb3.values[i])
    
    i= i+1

d3= pd.DataFrame(l3, columns=['Reaction names'])
d3.to_csv("increasing and decreasing and stable in anaerobic and not M9 media conditions")
d4= pd.DataFrame(l4, columns=['Reaction names'])
d4.to_csv("increasing and decreasing and stable in M9 media and not anaerobic conditions")



i= 0
l5= list()
l6= list()

while i < len(bigb4):
    
    if bigb4.values[i] in c.values and bigb4.values[i] not in f.values:
        l5.append(bigb4.values[i])
    elif bigb4.values[i] in f.values and bigb4.values[i] not in c.values:
        l6.append(bigb4.values[i])
    
    i= i+1

d5= pd.DataFrame(l5, columns=['Reaction names'])
d5.to_csv("increasing and decreasing and stable in anaerobic and not lactose conditions")
d6= pd.DataFrame(l6, columns=['Reaction names'])
d6.to_csv("increasing and decreasing and stable in lactose and not anaerobic conditions")

# %%
df= pd.read_csv('increasing and decreasing only reactions.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('increasing and decreasing only reactions anaerobic.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('increasing and decreasing only reactions study conditions.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('increasing and decreasing only reactions M9 media.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('increasing and decreasing only reactions lactose.csv')
f= df4.iloc[:, 1]

union = pd.Series(np.union1d(c, d))
intersect = pd.Series(np.intersect1d(c, d))
bigb2= union[~union.isin(intersect)]

union = pd.Series(np.union1d(c, e))
intersect = pd.Series(np.intersect1d(c, e))
bigb3= union[~union.isin(intersect)]

union = pd.Series(np.union1d(c, f))
intersect = pd.Series(np.intersect1d(c, f))
bigb4= union[~union.isin(intersect)]


i= 0
l1= list()
l2= list()

while i < len(bigb2):
    
    if bigb2.values[i] in c.values and bigb2.values[i] not in d.values:
        l1.append(bigb2.values[i])
    elif bigb2.values[i] in d.values and bigb2.values[i] not in c.values:
        l2.append(bigb2.values[i])
    
    i= i+1

d1= pd.DataFrame(l1, columns=['Reaction names'])
d1.to_csv("increasing and decreasing only in anaerobic and not study conditions")
d2= pd.DataFrame(l2, columns=['Reaction names'])
d2.to_csv("increasing and decreasing only in study and not anaerobic conditions")



i= 0
l3= list()
l4= list()

while i < len(bigb3):
    
    if bigb3.values[i] in c.values and bigb3.values[i] not in e.values:
        l3.append(bigb3.values[i])
    elif bigb3.values[i] in e.values and bigb3.values[i] not in c.values:
        l4.append(bigb3.values[i])
    
    i= i+1

d3= pd.DataFrame(l3, columns=['Reaction names'])
d3.to_csv("increasing and decreasing only in anaerobic and not M9 media conditions")
d4= pd.DataFrame(l4, columns=['Reaction names'])
d4.to_csv("increasing and decreasing only in M9 media and not anaerobic conditions")



i= 0
l5= list()
l6= list()

while i < len(bigb4):
    
    if bigb4.values[i] in c.values and bigb4.values[i] not in f.values:
        l5.append(bigb4.values[i])
    elif bigb4.values[i] in f.values and bigb4.values[i] not in c.values:
        l6.append(bigb4.values[i])
    
    i= i+1

d5= pd.DataFrame(l5, columns=['Reaction names'])
d5.to_csv("increasing and decreasing only in anaerobic and not lactose conditions")
d6= pd.DataFrame(l6, columns=['Reaction names'])
d6.to_csv("increasing and decreasing only in lactose and not anaerobic conditions")
